# %%
# 1
age  = 24
name = '권세진'

# %%
# 2
height = 168
dream = '지각하지 않기'

# %%
# 3
city = '인천광역시'
my_city = city
print(my_city, city)
# Out:
# 인천광역시 인천광역시

# %%
# 4
apple_count = 10
orange_count = 20
print(apple_count, orange_count)
# Out:
# 10 20

# %%
# 5
first_name = '세진'
last_name = '권'
full_name = first_name + last_name
print(full_name)
# Out:
# 세진권
