# %%
# 1
# 2번

# %%
# 2
# 2번

# %%
# 1
fruits = ['apple', 'banana', 'cherry']
print(fruits[0], fruits[2])
# Out:
# apple cherry

# %%
# 2
numbers = [1, 2, 3, 4, 5]
print(len(numbers))
# Out:
# 5

# %%
# 3
animals = ['cat', 'dog', 'bird']
animals.append('fish')
print(animals)
# Out:
# ['cat', 'dog', 'bird', 'fish']

# %%
# 4
numbers = [3, 6, 9]
numbers[0] *= 2
print(numbers)
# Out:
# [3, 12, 9]

# %%
# 5
str = 'Python-is-fun'
print(str.split('-'))
# Out:
# ['Python', 'is', 'fun']

# %%
# 6
my_tuple = 10, 20, 30
print(my_tuple[1])
# Out:
# 20

# %%
# 7
colors = ['red', 'blue', 'green']
colors[1] = 'yellow'
print(colors)
# Out:
# ['red', 'yellow', 'green']

# %%
# 8
# 숫자 1부터 10까지 중에서 짝수만을 추출해 새로운 리스트에 저장
even_num = [number for number in range(1, 11) if number % 2 ==0]
print(even_num)
# Out:
# [2, 4, 6, 8, 10]

# %%
# 9
words = ['Life', 'is', 'too', 'short']
print(words[0] + ' ' + words[1] + ' ' + words[2] + ' ' + words[3])

sentence = '-'.join(words)
print(sentence)
# Out:
# Life is too short
# Life-is-too-short

# %%
# 10
numbers = [1, 2, 3, 4, 5]
print(numbers[:3])
print(numbers[3:])
print(numbers[::-1])
# Out:
# [1, 2, 3]
# [4, 5]
# [5, 4, 3, 2, 1]
