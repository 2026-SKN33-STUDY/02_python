# %%
# # 1
# **셋(Set)의 특징**에 대한 설명 중 옳지 않은 것은 무엇인가요?
#
# 1. 셋은 중복된 요소를 허용하지 않는다.
# 2. 셋은 순서가 없는 자료형이다.
# 3. 셋은 인덱스를 사용해 요소에 접근할 수 있다.
# 4. 셋은 다양한 자료형을 요소로 가질 수 있다.
# 5. `add()` 메서드를 사용하여 새로운 요소를 추가할 수 있다.

# 정답: 3

# %%
# 2
# 다음 코드의 실행 결과를 고르세요.
info = {'name': 'Kim', 'age': 30, 'city': 'Seoul'}
print(info.get('country', 'Unknown'))

# Unknown
# Out:
# Unknown

# %%
# 1
fruits = {'apple', 'banana', 'cherry'}
print(fruits)
print(type(fruits))
# Out:
# {'apple', 'cherry', 'banana'}
# <class 'set'>

# %%
# 2
animals = {'cat', 'dog', 'bird', 'fish'}
animals.remove('bird')
print(animals)
# Out:
# {'fish', 'dog', 'cat'}

# %%
# 3
set1 = {1, 2, 3}
set2 = {3, 4, 5}
print(set1 | set2)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 4
student = {
    'name':'John',
    'age':20,
    'major':'Computer Science'
}
print(student.get('age'))
print(student['age'])
# Out:
# 20
# 20

# %%
# 5
scores = {
    'math':80,
    'english':90
}
# 'math'의 값을 95로 변경하고 딕셔너리를 출력
scores['math'] = 95
print(scores)
# Out:
# {'math': 95, 'english': 90}

# %%
# 6
colors1 = {'red', 'blue', 'green'}
colors2 = {'blue', 'yellow', 'pink'}
print(colors1 & colors2)
# Out:
# {'blue'}

# %%
# 7
info = {
    'name':'Alice',
    'age':25,
    'city':'Seoul'
}
print(info.keys())
print(info.values())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Alice', 25, 'Seoul'])

# %%
# 8
students = {
    'student1': 85,
    'student2': 90,
    'student3': 95
}
students.pop('student2')
print(students)
# Out:
# {'student1': 85, 'student3': 95}

# %%
# 9
numbers = {1, 2, 3, 4, 5}
squares = {numbers : numbers **2 for numbers in numbers}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# 10
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print(A.symmetric_difference(B))
# Out:
# {1, 2, 5, 6}
