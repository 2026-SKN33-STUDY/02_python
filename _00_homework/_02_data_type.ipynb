# %%
# 1
num1 = 10
num2 = 5
sum_result = num1 + num2
print(sum_result)
# Out:
# 15

# %%
# 2
x = 7.5
y = 2
result = x / y
print(result)
# Out:
# 3.75

# %%
# 3
is_student = True
print(is_student, type(is_student))
# Out:
# True <class 'bool'>

# %%
# 4
num1 = 15
num2 = 4
print(num1 // num2, num1 % num2)
# Out:
# 3 3

# %%
# 5
greeting_message = "Hello"
greeting_target = "World"
print(greeting_message + greeting_target)
# Out:
# HelloWorld

# %%
# 6
base, exponent = 2, 5
print(base ** exponent)
# Out:
# 32

# %%
# 7
number = 3
print(number % 2 == 0)
# Out:
# False

# %%
# 8
age = 24
city = '인천광역시'
print(f"나는 {age}살이고, {city}에 살고 있습니다.")
# Out:
# 나는 24살이고, 인천광역시에 살고 있습니다.
